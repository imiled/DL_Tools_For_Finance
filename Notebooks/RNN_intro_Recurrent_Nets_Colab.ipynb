# %% [markdown]
# # Introduction to Recurrent Neural Networks
#
# Classical neural networks, including convolutional ones, suffer from two severe limitations:
#
# + They only accept a fixed-sized vector as input and produce a fixed-sized vector as output.
# + They do not consider the sequential nature of some data (language, video frames, time series, etc.). In other words, they do not have memory (not until the attention mechanism came to live!).
#
# Recurrent neural networks overcome these limitations by allowing to operate over sequences of vectors (in the input, in the output, or both).

# %% [markdown]
# ## Vanilla Recurrent Neural Network
#
# + We can think of the **hidden state** $s_t$ as a memory of the network that captures information about the previous steps.
# + The RNN **shares the parameters** $U,V,W$ across all time steps.
#
# <img src="https://github.com/FasterUpperBeyond/deep-learning-images/blob/master/imgs/rnn_vanilla.png?raw=1" height="250px"/>

# %% [markdown]
# ## Unrolling in time of a RNN
#
# By unrolling we mean that we write out the network for the complete sequence. Note that the state at time $t$ depends on current input $x_t$ and previsous state $s_{t-1}$.
#
# $$ s_t = \mbox{tanh }(Ux_t + W s_{t-1}) $$
# $$ y_t = \mbox{softmax }(V s_t) $$
#
# <img src="https://github.com/FasterUpperBeyond/deep-learning-images/blob/master/imgs/rnn_unrolling.png?raw=1" alt="" height="300px;"/>

# %% [markdown]
# ## RNN inputs and ouputs
#
# <img src="https://github.com/FasterUpperBeyond/deep-learning-images/blob/master/imgs/rnn_kar.png?raw=1" alt="" style="width: 600px;"/>
#
# Source: http://karpathy.github.io/2015/05/21/rnn-effectiveness/

# %% [markdown]
# ## RNN capabilities
#
# From Karpahty's blog:
#
#
# ''RNNs combine the input vector with their state vector with a fixed (but learned) function to produce a new state vector. This can in programming terms be interpreted as running a fixed program with certain inputs and some internal variables. Viewed this way, RNNs essentially describe programs. In fact, **it is known that RNNs are Turing-Complete** in the sense that they can to simulate arbitrary programs (with proper weights).''
#
# RNN have shown success in:
#
# + Language modeling and generation.
# + Machine Translation.
# + Speech Recognition.
# + Image Description.
# + Question Answering.
# + Time series analysis.
# + Session based recommender systems
# + Etc.

# %% [markdown]
# ## RNN Training
#
# Training a RNN is similar to training a traditional NN, but with some modifications. The main reason is that parameters are shared by all time steps: in order to compute the gradient at $t=4$, we need to propagate 3 steps and sum up the gradients. This is called **Backpropagation through time (BPTT)**. Thanks god, this is automatically handled by the optimizer =)
#
# Recurrent neural networks propagate weight matrices from one time-step to the next. Recall the goal of a RNN implementation is to enable propagating context information through faraway time-steps. When these propagation results in a long series of matrix multiplications, **weights can vanish or explode**.
#
# Once the gradient value grows extremely large, it causes an overflow (i.e. ``NaN``) which is easily detectable at runtime; this issue is called the *Gradient Explosion Problem*. It is normally avoided by clipping gradients during training (use the parameter `clipnorm` in any optimizer), as introduced by [Thomas Mikolov](https://research.fb.com/people/mikolov-tomas/).
#
# <img src="https://github.com/FasterUpperBeyond/deep-learning-images/blob/master/imgs/rnn_exploding.png?raw=1" alt="" style="width: 400px;"/>
#
# When the gradient value goes to zero, however, it can go undetected while drastically reducing the learning quality of the model for far-away words in the corpus; this issue is called the *Vanishing Gradient Problem*. This issue is avoided with better initialization schemmes (in Keras, the `kernel_initializer` is set to 'glorot_uniform' and the  `recurrent_initializer` to 'orthogonal', see the [documentation](https://keras.io/layers/recurrent/)).

# %% [markdown]
# # Gated Units
#
# The transition from hidden state $h_{t-1}$ to $h_{t}$ in vanilla RNN is defined by using an affine transformation and a point-wise nonlinearity.
#
# What motivates the use of gated units? Although RNNs can theoretically capture long-term dependencies, they are very hard to actually train to do this. **Gated recurrent units are designed** in a manner to have more persistent memory thereby making it easier for RNNs **to capture long-term dependencies**.
#
# The most important types of gated RNNs are:
#
# + Long Short Term Memories (LSTM). It was introduced by S.Hochreiter and J.Schmidhuber in 1997 and is widely used. LSTM is very good in the long run due to its high complexity.
# + Gated Recurrent Units (GRU). It was recently introduced by K.Cho. It is simpler than LSTM, fasters and optimizes quicker.

# %% [markdown]
# #### LSTM
#
# The key idea of LSTMs is the cell state $C$, the horizontal line running through the top of the diagram.
#
# The cell state is kind of like a conveyor belt. It runs straight down the entire chain, with only some minor linear interactions. It’s very easy for information to just flow along it unchanged.
#
# <img src="https://github.com/FasterUpperBeyond/deep-learning-images/blob/master/imgs/rnn_lstm.png?raw=1" alt="Source: http://colah.github.io/posts/2015-08-Understanding-LSTMs/" style="width: 600px;"/>
#
# LSTM has the ability to remove or add information to the cell state, carefully regulated by structures called gates.
#
# Gates are a way to optionally let information through. They are composed out of a *sigmoid* neural net layer and a pointwise multiplication operation.
#
# Let us see how a LSTM uses $h_{t-1}, C_{t-1}$ and $x_{t}$ to generate the next hidden states $C_t, h_{t}$:
#
# $$ f_t = \sigma(W_f \cdot [h_{t-1}, x_t]) \mbox{ (Forget gate)} $$
# $$ i_t = \sigma(W_i \cdot [h_{t-1}, x_t]) \mbox{ (Input gate)} $$
# $$ \tilde C_t = \operatorname{tanh}(W_C \cdot [h_{t-1}, x_t]) $$
# $$ C_t = f_t * C_{t-1} + i_t * \tilde C_t \mbox{ (Update gate)} $$
# $$ o_t = \sigma(W_o \cdot [h_{t-1}, x_t]) $$
# $$ h_t = o_t * \operatorname{tanh}(C_t) \mbox{ (Output gate)} $$
#
# There are other variants of LSTM (f.e. LSTM with peephole connections of Gers & Schmidhuber (2000))

# %% [markdown]
# #### GRU
#
# <img src="https://github.com/FasterUpperBeyond/deep-learning-images/blob/master/imgs/rnn_gru.png?raw=1" alt="Source: http://colah.github.io/posts/2015-08-Understanding-LSTMs/" width="300px;"/>
#
#
# Let us see how a GRU uses $h_{t-1}$ and $x_{t}$ to generate the next hidden state $h_{t}$.
#
# $$ z_{t} = \sigma(W_z \cdot [x_{t}, h_{t-1}]) \mbox{ (Update gate)}$$
# $$ r_{t} = \sigma(W_r \cdot [x_{t}, h_{t-1}]) \mbox{ (Reset gate)}$$
# $$ \tilde{h}_{t} = \operatorname{tanh}(r_{t} \cdot  [x_{t}, r_t \circ h_{t-1}]   ) \mbox{ (New memory)}$$
# $$ h_{t} = (1 - z_{t}) \circ \tilde{h}_{t-1} + z_{t} \circ h_{t} \mbox{ (Hidden state)}$$
#
# It combines the forget and input gates into a single “update gate.” It also merges the cell state and hidden state, and makes some other changes. The resulting model is simpler than standard LSTM models.

# %% [markdown]
# # Example: Learning to predict a sequence from another sequence
#
# The proposed task is to predict a signal (e.g., a cosine) out of phase from the original signal. This would be real hard for a feedforward NN, since for an input value, we can have more than one possible outputs. The correct ouput depends not just on the current input, but also on the inputs previous to it. Thus, it can only be solved with a memory.
#
# This is the classical example of an oscilloscope:
#
# ![](https://jeelabs.org/wp-content/uploads/2012/03/SCR40.png)

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
try:
    from tensorflow.python.util import module_wrapper as deprecation
except ImportError:
    from tensorflow.python.util import deprecation_wrapper as deprecation
deprecation._PER_MODULE_WARNING_LIMIT = 0

# %%
f = lambda x: (np.cos(x)**2 + np.sin(x))/2.0
nb_samples = 5000 

phase = -np.pi / 4.0
x = np.linspace(-5*np.pi, 5*np.pi, nb_samples)
x_train = f(x)
y_train = f(x+phase)

# %%
plt.plot(x, x_train, 'b')
plt.plot(x, y_train, 'g')
plt.show()

# %%
plt.plot(x_train, y_train);

# %% [markdown]
# ## Handling sequences with RNNs
#
# Whenever you train or test your LSTM/GRU, you first have to build your input matrix $X$ of shape ``nb_samples``, ``timesteps``, ``input_dim`` where your batch size divides ``nb_samples``.
#
# <img src="https://www.tensorflow.org/tutorials/structured_data/images/time_series.png" width="300px">
#
# For instance, if ``nb_samples=1024`` and ``batch_size=64``, it means that your model will receive blocks of 64 samples, compute each output (whatever the number of timesteps is for every sample), average the gradients and propagate it to update the parameters vector.
#
# > By default, **Keras shuffles (permutes) the samples in $X$** and the dependencies between $X_i$ and $X_{i+1}$ are lost.
#
# With the stateful model, all the states are propagated to the next batch. It means that the state of the sample located at index $i$, $X_i$, will be used in the computation of the sample $X_{i+bs}$ in the next batch, where $bs$ is the batch size (no shuffling).
#
# > Keras requires the batch size in ``stateful`` mode and ``shuffle=False``.
#
# In statefull mode, you have to restart the internal state of the cell after each epoch. In stateless mode this is done after each batch.

# %%
batch_size = 25
tsteps = 1
input_dim = 1
# Give x_train the shape required by the RNN
x_train_rnn = np.reshape(x_train, newshape=(nb_samples, tsteps, input_dim))

# %%
epochs = 50

tf.keras.backend.clear_session()
print('Creating Model')
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(50,
  batch_input_shape=(batch_size, tsteps, input_dim),
  return_sequences=True,
  stateful=True))
model.add(tf.keras.layers.LSTM(50,
  return_sequences=False,
  stateful=True))
model.add(tf.keras.layers.Dense(1))
model.compile(loss='mse', optimizer='rmsprop')
model.summary()
# Out:
# Creating Model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (25, 1, 50)               10400
# _________________________________________________________________
# lstm_1 (LSTM)                (25, 50)                  20200
# _________________________________________________________________
# dense (Dense)                (25, 1)                   51
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
print('Training')
for i in range(epochs):
    print('Epoch', i, '/', epochs)
    model.fit(x_train_rnn,
              y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=1,
              shuffle=False)
    model.reset_states()

print('Predicting')
predicted_output = model.predict(x_train_rnn, batch_size=batch_size)
err = np.mean((y_train-predicted_output)**2)
print("Error in reconstruction is %0.2f" % err)
# Out:
# Training
# Epoch 0 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 7s 1ms/sample - loss: 0.0151
# Epoch 1 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 246us/sample - loss: 0.0057
# Epoch 2 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 262us/sample - loss: 0.0054
# Epoch 3 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 262us/sample - loss: 0.0049
# Epoch 4 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 266us/sample - loss: 0.0045
# Epoch 5 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 286us/sample - loss: 0.0042
# Epoch 6 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 255us/sample - loss: 0.0043
# Epoch 7 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 261us/sample - loss: 0.0043
# Epoch 8 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 269us/sample - loss: 0.0043
# Epoch 9 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 263us/sample - loss: 0.0038
# Epoch 10 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 272us/sample - loss: 0.0034
# Epoch 11 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 287us/sample - loss: 0.0031
# Epoch 12 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 281us/sample - loss: 0.0029
# Epoch 13 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 263us/sample - loss: 0.0025
# Epoch 14 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 287us/sample - loss: 0.0025
# Epoch 15 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 260us/sample - loss: 0.0021
# Epoch 16 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 242us/sample - loss: 0.0019
# Epoch 17 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 250us/sample - loss: 0.0016
# Epoch 18 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 250us/sample - loss: 0.0015
# Epoch 19 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 249us/sample - loss: 0.0013
# Epoch 20 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 253us/sample - loss: 0.0012
# Epoch 21 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 248us/sample - loss: 0.0011
# Epoch 22 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 251us/sample - loss: 9.4967e-04
# Epoch 23 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 242us/sample - loss: 8.8072e-04
# Epoch 24 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 247us/sample - loss: 8.1120e-04
# Epoch 25 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 259us/sample - loss: 7.4741e-04
# Epoch 26 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 233us/sample - loss: 6.7690e-04
# Epoch 27 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 246us/sample - loss: 6.1205e-04
# Epoch 28 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 259us/sample - loss: 5.7391e-04
# Epoch 29 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 249us/sample - loss: 5.5099e-04
# Epoch 30 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 249us/sample - loss: 4.8142e-04
# Epoch 31 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 250us/sample - loss: 6.3812e-04
# Epoch 32 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 250us/sample - loss: 8.7353e-04
# Epoch 33 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 274us/sample - loss: 7.3288e-04
# Epoch 34 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 241us/sample - loss: 5.7764e-04
# Epoch 35 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 253us/sample - loss: 0.0015
# Epoch 36 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 251us/sample - loss: 9.1456e-04
# Epoch 37 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 252us/sample - loss: 7.8269e-04
# Epoch 38 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 243us/sample - loss: 7.4164e-04
# Epoch 39 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 255us/sample - loss: 6.2808e-04
# Epoch 40 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 254us/sample - loss: 6.6075e-04
# Epoch 41 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 242us/sample - loss: 5.9852e-04
# Epoch 42 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 244us/sample - loss: 4.7673e-04
# Epoch 43 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 250us/sample - loss: 4.3810e-04
# Epoch 44 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 259us/sample - loss: 5.7972e-04
# Epoch 45 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 264us/sample - loss: 5.5810e-04
# Epoch 46 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 249us/sample - loss: 3.4423e-04
# Epoch 47 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 240us/sample - loss: 7.1052e-04
# Epoch 48 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 250us/sample - loss: 8.0489e-04
# Epoch 49 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 257us/sample - loss: 3.4329e-04
# Predicting
# Error in reconstruction is 0.31

# %%
plt.figure(figsize=(10,6))
plt.plot(x, predicted_output, 'b', x, y_train, 'r')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(x_train, predicted_output, 'b', x_train, y_train, 'r')
plt.show()

# %% [markdown]
# ## Do the same with a GRU Cell

# %%
epochs = 50

tf.keras.backend.clear_session()
print('Creating Model')
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.GRU(50,
               batch_input_shape=(batch_size, tsteps, input_dim),
               return_sequences=True,
               stateful=True))
model.add(tf.keras.layers.GRU(50,
               return_sequences=False,
               stateful=True))
model.add(tf.keras.layers.Dense(1))
model.compile(loss='mse', optimizer='rmsprop')
model.summary()
print('Training')
for i in range(epochs):
    print('Epoch', i, '/', epochs)
    model.fit(x_train_rnn,
              y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=1,
              shuffle=False)
    model.reset_states()

print('Predicting')
predicted_output = model.predict(x_train_rnn, batch_size=batch_size)
err = np.mean((y_train-predicted_output)**2)
print("Error in reconstruction is %0.2f" % err)
print('Ploting Results')
plt.figure(figsize=(10, 6))
plt.plot(x, predicted_output, 'b', x, y_train, 'r')
plt.show()    

plt.figure(figsize=(10,6))
plt.plot(x_train, predicted_output, 'b', x_train, y_train, 'r')
plt.show()
# Out:
# Creating Model
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (25, 1, 50)               7800
# _________________________________________________________________
# gru_2 (GRU)                  (25, 50)                  15150
# _________________________________________________________________
# dense_1 (Dense)              (25, 1)                   51
# =================================================================
# Total params: 23,001
# Trainable params: 23,001
# Non-trainable params: 0
# _________________________________________________________________
# Training
# Epoch 0 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 457us/step - loss: 0.0115
# Epoch 1 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 323us/step - loss: 0.0060
# Epoch 2 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 321us/step - loss: 0.0059
# Epoch 3 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 327us/step - loss: 0.0057
# Epoch 4 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 328us/step - loss: 0.0056
# Epoch 5 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 330us/step - loss: 0.0056
# Epoch 6 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 324us/step - loss: 0.0056
# Epoch 7 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 322us/step - loss: 0.0052
# Epoch 8 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 328us/step - loss: 0.0052
# Epoch 9 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 327us/step - loss: 0.0053
# Epoch 10 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 323us/step - loss: 0.0054
# Epoch 11 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 323us/step - loss: 0.0056
# Epoch 12 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 324us/step - loss: 0.0052
# Epoch 13 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 324us/step - loss: 0.0053
# Epoch 14 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 326us/step - loss: 0.0054
# Epoch 15 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 319us/step - loss: 0.0056
# Epoch 16 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 326us/step - loss: 0.0057
# Epoch 17 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 329us/step - loss: 0.0062
# Epoch 18 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 327us/step - loss: 0.0068
# Epoch 19 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 316us/step - loss: 0.0072
# Epoch 20 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 322us/step - loss: 0.0086
# Epoch 21 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 320us/step - loss: 0.0129
# Epoch 22 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 322us/step - loss: 0.0202
# Epoch 23 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 325us/step - loss: 0.0146
# Epoch 24 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 324us/step - loss: 0.0108
# Epoch 25 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 324us/step - loss: 0.0093
# Epoch 26 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 323us/step - loss: 0.0082
# Epoch 27 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 321us/step - loss: 0.0075
# Epoch 28 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 322us/step - loss: 0.0062
# Epoch 29 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 325us/step - loss: 0.0046
# Epoch 30 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 326us/step - loss: 0.0035
# Epoch 31 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 319us/step - loss: 0.0029
# Epoch 32 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 326us/step - loss: 0.0025
# Epoch 33 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 324us/step - loss: 0.0022
# Epoch 34 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 323us/step - loss: 0.0020
# Epoch 35 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 328us/step - loss: 0.0018
# Epoch 36 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 328us/step - loss: 0.0016
# Epoch 37 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 334us/step - loss: 0.0014
# Epoch 38 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 329us/step - loss: 0.0013
# Epoch 39 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 321us/step - loss: 0.0012
# Epoch 40 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 326us/step - loss: 0.0012
# Epoch 41 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 321us/step - loss: 0.0010
# Epoch 42 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 330us/step - loss: 9.8804e-04
# Epoch 43 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 321us/step - loss: 9.0875e-04
# Epoch 44 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 327us/step - loss: 8.5661e-04
# Epoch 45 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 328us/step - loss: 7.7872e-04
# Epoch 46 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 320us/step - loss: 6.9514e-04
# Epoch 47 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 328us/step - loss: 6.1375e-04
# Epoch 48 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 324us/step - loss: 5.3571e-04
# Epoch 49 / 50
# Epoch 1/1
# 5000/5000 [==============================] - 2s 333us/step - loss: 4.7143e-04
# Predicting
# Error in reconstruction is 0.35
# Ploting Results

# %% [markdown]
# ## How does the time dependency (batch size, here) affect the results?

# %%
batch_size = 10
tsteps = 1
input_dim = 1
# Give x_train the shape required by the RNN
x_train_rnn = np.reshape(x_train, newshape=(nb_samples, tsteps, input_dim))

epochs = 50

tf.keras.backend.clear_session()
print('Creating Model')
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(50,
               batch_input_shape=(batch_size, tsteps, input_dim),
               return_sequences=True,
               stateful=True))
model.add(tf.keras.layers.LSTM(50,
               return_sequences=False,
               stateful=True))
model.add(tf.keras.layers.Dense(1))

model.compile(loss='mse', optimizer='rmsprop')
model.summary()
print('Training')
for i in range(epochs):
    print('Epoch', i, '/', epochs)
    model.fit(x_train_rnn,
              y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=1,
              shuffle=False)
    model.reset_states()

print('Predicting')
predicted_output = model.predict(x_train_rnn, batch_size=batch_size)
err = np.mean((y_train-predicted_output)**2)
print("Error in reconstruction is %0.2f" % err)
print('Ploting Results')
plt.figure(figsize=(10, 6))
plt.plot(x, predicted_output, 'b', x, y_train, 'r')
plt.show()    

plt.figure(figsize=(10,6))
plt.plot(x_train, predicted_output, 'b', x_train, y_train, 'r')
plt.show()
# Out:
# Creating Model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (10, 1, 50)               10400
# _________________________________________________________________
# lstm_1 (LSTM)                (10, 50)                  20200
# _________________________________________________________________
# dense (Dense)                (10, 1)                   51
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________
# Training
# Epoch 0 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 6s 1ms/sample - loss: 0.0040
# Epoch 1 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 620us/sample - loss: 0.0046
# Epoch 2 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 630us/sample - loss: 0.0045
# Epoch 3 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 615us/sample - loss: 0.0041
# Epoch 4 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 649us/sample - loss: 0.0037
# Epoch 5 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 623us/sample - loss: 0.0032
# Epoch 6 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 629us/sample - loss: 0.0029
# Epoch 7 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 626us/sample - loss: 0.0026
# Epoch 8 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 622us/sample - loss: 0.0024
# Epoch 9 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 637us/sample - loss: 0.0021
# Epoch 10 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 609us/sample - loss: 0.0021
# Epoch 11 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 646us/sample - loss: 0.0021
# Epoch 12 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 651us/sample - loss: 0.0015
# Epoch 13 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 617us/sample - loss: 0.0019
# Epoch 14 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 625us/sample - loss: 0.0013
# Epoch 15 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 639us/sample - loss: 8.9237e-04
# Epoch 16 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 619us/sample - loss: 7.7630e-04
# Epoch 17 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 628us/sample - loss: 6.8625e-04
# Epoch 18 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 622us/sample - loss: 4.9931e-04
# Epoch 19 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 620us/sample - loss: 4.4513e-04
# Epoch 20 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 610us/sample - loss: 4.5083e-04
# Epoch 21 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 613us/sample - loss: 4.4606e-04
# Epoch 22 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 629us/sample - loss: 3.8066e-04
# Epoch 23 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 672us/sample - loss: 4.2508e-04
# Epoch 24 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 631us/sample - loss: 3.4024e-04
# Epoch 25 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 627us/sample - loss: 2.4634e-04
# Epoch 26 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 654us/sample - loss: 1.7628e-04
# Epoch 27 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 625us/sample - loss: 1.4849e-04
# Epoch 28 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 630us/sample - loss: 1.3458e-04
# Epoch 29 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 637us/sample - loss: 1.1769e-04
# Epoch 30 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 628us/sample - loss: 1.3976e-04
# Epoch 31 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 623us/sample - loss: 1.3671e-04
# Epoch 32 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 630us/sample - loss: 1.5920e-04
# Epoch 33 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 636us/sample - loss: 1.2829e-04
# Epoch 34 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 617us/sample - loss: 2.0887e-04
# Epoch 35 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 611us/sample - loss: 4.0350e-04
# Epoch 36 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 635us/sample - loss: 4.7690e-04
# Epoch 37 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 607us/sample - loss: 1.6288e-04
# Epoch 38 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 626us/sample - loss: 2.7648e-04
# Epoch 39 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 613us/sample - loss: 1.3220e-04
# Epoch 40 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 624us/sample - loss: 1.0316e-04
# Epoch 41 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 666us/sample - loss: 1.0606e-04
# Epoch 42 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 642us/sample - loss: 1.6883e-04
# Epoch 43 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 666us/sample - loss: 1.2446e-04
# Epoch 44 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 657us/sample - loss: 1.5848e-04
# Epoch 45 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 644us/sample - loss: 5.8075e-05
# Epoch 46 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 630us/sample - loss: 6.3337e-05
# Epoch 47 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 614us/sample - loss: 5.3612e-05
# Epoch 48 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 622us/sample - loss: 4.4781e-05
# Epoch 49 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 3s 621us/sample - loss: 4.0451e-05
# Predicting
# Error in reconstruction is 0.36
# Ploting Results

# %%
batch_size = 100
tsteps = 1
input_dim = 1
# Give x_train the shape required by the RNN
x_train_rnn = np.reshape(x_train, newshape=(nb_samples, tsteps, input_dim))

epochs = 50

tf.keras.backend.clear_session()
print('Creating Model')
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(50,
               batch_input_shape=(batch_size, tsteps, input_dim),
               return_sequences=True,
               stateful=True))
model.add(tf.keras.layers.LSTM(50,
               return_sequences=False,
               stateful=True))
model.add(tf.keras.layers.Dense(1))

model.compile(loss='mse', optimizer='rmsprop')
model.summary()
print('Training')
for i in range(epochs):
    print('Epoch', i, '/', epochs)
    model.fit(x_train_rnn,
              y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=1,
              shuffle=False)
    model.reset_states()

print('Predicting')
predicted_output = model.predict(x_train_rnn, batch_size=batch_size)
err = np.mean((y_train-predicted_output)**2)
print("Error in reconstruction is %0.2f" % err)
print('Ploting Results')
plt.figure(figsize=(10, 6))
plt.plot(x, predicted_output, 'b', x, y_train, 'r')
plt.show()    

plt.figure(figsize=(10,6))
plt.plot(x_train, predicted_output, 'b', x_train, y_train, 'r')
plt.show()
# Out:
# Creating Model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (100, 1, 50)              10400
# _________________________________________________________________
# lstm_1 (LSTM)                (100, 50)                 20200
# _________________________________________________________________
# dense (Dense)                (100, 1)                  51
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________
# Training
# Epoch 0 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 4s 700us/sample - loss: 0.1808
# Epoch 1 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.1239
# Epoch 2 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0689
# Epoch 3 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 68us/sample - loss: 0.0360
# Epoch 4 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 65us/sample - loss: 0.0269
# Epoch 5 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0221
# Epoch 6 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 68us/sample - loss: 0.0188
# Epoch 7 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0169
# Epoch 8 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0161
# Epoch 9 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0156
# Epoch 10 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0151
# Epoch 11 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0146
# Epoch 12 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 67us/sample - loss: 0.0141
# Epoch 13 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0136
# Epoch 14 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0131
# Epoch 15 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0126
# Epoch 16 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0121
# Epoch 17 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0117
# Epoch 18 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.0112
# Epoch 19 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.0108
# Epoch 20 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 65us/sample - loss: 0.0104
# Epoch 21 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.0100
# Epoch 22 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0097
# Epoch 23 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0093
# Epoch 24 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0090
# Epoch 25 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 68us/sample - loss: 0.0087
# Epoch 26 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0083
# Epoch 27 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.0080
# Epoch 28 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0077
# Epoch 29 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0073
# Epoch 30 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 67us/sample - loss: 0.0070
# Epoch 31 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0067
# Epoch 32 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0065
# Epoch 33 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.0062
# Epoch 34 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 68us/sample - loss: 0.0060
# Epoch 35 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0058
# Epoch 36 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0056
# Epoch 37 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 66us/sample - loss: 0.0053
# Epoch 38 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0049
# Epoch 39 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0046
# Epoch 40 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0043
# Epoch 41 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 66us/sample - loss: 0.0041
# Epoch 42 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.0039
# Epoch 43 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 65us/sample - loss: 0.0038
# Epoch 44 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 66us/sample - loss: 0.0038
# Epoch 45 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 70us/sample - loss: 0.0037
# Epoch 46 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0036
# Epoch 47 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0039
# Epoch 48 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0037
# Epoch 49 / 50
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0040
# Predicting
# Error in reconstruction is 0.27
# Ploting Results

# %% [markdown]
# Clip the value of the gradient to prevent exploiding gradients when handling long-term dependencies.

# %%
batch_size = 100
tsteps = 1
input_dim = 1
# Give x_train the shape required by the RNN
x_train_rnn = np.reshape(x_train, newshape=(nb_samples, tsteps, input_dim))

epochs = 100

tf.keras.backend.clear_session()
print('Creating Model')
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(50,
               batch_input_shape=(batch_size, tsteps, input_dim),
               return_sequences=True,
               stateful=True))
model.add(tf.keras.layers.LSTM(50,
               return_sequences=False,
               stateful=True))
model.add(tf.keras.layers.Dense(1))

optimizer = tf.keras.optimizers.RMSprop(clipvalue=0.5)
model.compile(loss='mse', optimizer=optimizer)
model.summary()
print('Training')
for i in range(epochs):
    print('Epoch', i, '/', epochs)
    model.fit(x_train_rnn,
              y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=1,
              shuffle=False)
    model.reset_states()

print('Predicting')
predicted_output = model.predict(x_train_rnn, batch_size=batch_size)
err = np.mean((y_train-predicted_output)**2)
print("Error in reconstruction is %0.2f" % err)
print('Ploting Results')
plt.figure(figsize=(10, 6))
plt.plot(x, predicted_output, 'b', x, y_train, 'r')
plt.show()    

plt.figure(figsize=(10,6))
plt.plot(x_train, predicted_output, 'b', x_train, y_train, 'r')
plt.show()
# Out:
# Creating Model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (100, 1, 50)              10400
# _________________________________________________________________
# lstm_1 (LSTM)                (100, 50)                 20200
# _________________________________________________________________
# dense (Dense)                (100, 1)                  51
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________
# Training
# Epoch 0 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 4s 754us/sample - loss: 0.1742
# Epoch 1 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 76us/sample - loss: 0.1313
# Epoch 2 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0715
# Epoch 3 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0356
# Epoch 4 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 65us/sample - loss: 0.0258
# Epoch 5 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0208
# Epoch 6 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0174
# Epoch 7 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 65us/sample - loss: 0.0156
# Epoch 8 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0151
# Epoch 9 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0148
# Epoch 10 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0146
# Epoch 11 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0142
# Epoch 12 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0138
# Epoch 13 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0134
# Epoch 14 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0130
# Epoch 15 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.0125
# Epoch 16 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 75us/sample - loss: 0.0120
# Epoch 17 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0115
# Epoch 18 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.0110
# Epoch 19 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 75us/sample - loss: 0.0106
# Epoch 20 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0103
# Epoch 21 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 67us/sample - loss: 0.0099
# Epoch 22 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0096
# Epoch 23 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0093
# Epoch 24 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 67us/sample - loss: 0.0090
# Epoch 25 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 76us/sample - loss: 0.0088
# Epoch 26 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0086
# Epoch 27 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0084
# Epoch 28 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0083
# Epoch 29 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0081
# Epoch 30 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 65us/sample - loss: 0.0080
# Epoch 31 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0078
# Epoch 32 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0077
# Epoch 33 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0075
# Epoch 34 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 66us/sample - loss: 0.0074
# Epoch 35 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 71us/sample - loss: 0.0072
# Epoch 36 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0070
# Epoch 37 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0069
# Epoch 38 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0067
# Epoch 39 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0065
# Epoch 40 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 59us/sample - loss: 0.0064
# Epoch 41 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.0063
# Epoch 42 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0061
# Epoch 43 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 71us/sample - loss: 0.0060
# Epoch 44 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.0060
# Epoch 45 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 65us/sample - loss: 0.0059
# Epoch 46 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0058
# Epoch 47 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0057
# Epoch 48 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0057
# Epoch 49 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0056
# Epoch 50 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0054
# Epoch 51 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0053
# Epoch 52 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0050
# Epoch 53 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.0048
# Epoch 54 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0047
# Epoch 55 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 70us/sample - loss: 0.0047
# Epoch 56 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 69us/sample - loss: 0.0046
# Epoch 57 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 70us/sample - loss: 0.0045
# Epoch 58 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0044
# Epoch 59 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 68us/sample - loss: 0.0042
# Epoch 60 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 68us/sample - loss: 0.0041
# Epoch 61 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0039
# Epoch 62 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 69us/sample - loss: 0.0037
# Epoch 63 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0035
# Epoch 64 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0033
# Epoch 65 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 71us/sample - loss: 0.0032
# Epoch 66 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 66us/sample - loss: 0.0032
# Epoch 67 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0030
# Epoch 68 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0033
# Epoch 69 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0034
# Epoch 70 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 69us/sample - loss: 0.0041
# Epoch 71 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0056
# Epoch 72 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 66us/sample - loss: 0.0032
# Epoch 73 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 65us/sample - loss: 0.0034
# Epoch 74 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0044
# Epoch 75 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0041
# Epoch 76 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 66us/sample - loss: 0.0040
# Epoch 77 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0037
# Epoch 78 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 65us/sample - loss: 0.0039
# Epoch 79 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0043
# Epoch 80 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0033
# Epoch 81 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 69us/sample - loss: 0.0033
# Epoch 82 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.0054
# Epoch 83 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0028
# Epoch 84 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0029
# Epoch 85 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 65us/sample - loss: 0.0098
# Epoch 86 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0026
# Epoch 87 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 66us/sample - loss: 0.0032
# Epoch 88 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 65us/sample - loss: 0.0030
# Epoch 89 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 63us/sample - loss: 0.0031
# Epoch 90 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 64us/sample - loss: 0.0043
# Epoch 91 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0024
# Epoch 92 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 66us/sample - loss: 0.0029
# Epoch 93 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0045
# Epoch 94 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 66us/sample - loss: 0.0026
# Epoch 95 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 65us/sample - loss: 0.0023
# Epoch 96 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0063
# Epoch 97 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0022
# Epoch 98 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 62us/sample - loss: 0.0027
# Epoch 99 / 100
# Train on 5000 samples
# 5000/5000 [==============================] - 0s 61us/sample - loss: 0.0061
# Predicting
# Error in reconstruction is 0.49
# Ploting Results

# %% [markdown]
# # Exercise: try to predict a periodic function
#
# Before doing so, what do you expect to happen? Will the RNN be able to learn something? If so, what?

# %%
f = lambda x: np.cos(x)
nb_samples = 5000 
x_train = np.linspace(-5*np.pi, 5*np.pi, nb_samples)
y_train = f(x_train)
x_test = np.linspace(5*np.pi, 7*np.pi, nb_samples/5)
y_test = f(x_test)

plt.plot(x_train, y_train, 'b')
plt.plot(x_test, y_test, 'r')
plt.show()

# %%
batch_size = 25
tsteps = 1
input_dim = 1
# Give x_train the shape required by the RNN
x_train_rnn = np.reshape(x_train, newshape=(nb_samples, tsteps, input_dim))

epochs = 25

tf.keras.backend.clear_session()
print('Creating Model')
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(50,
               batch_input_shape=(batch_size, tsteps, input_dim),
               return_sequences=True,
               stateful=True))
model.add(tf.keras.layers.LSTM(50,
               return_sequences=False,
               stateful=True))
model.add(tf.keras.layers.Dense(1))

model.compile(loss='mse', optimizer='rmsprop')
model.summary()
print('Training')
for i in range(epochs):
    print('Epoch', i, '/', epochs)
    model.fit(x_train_rnn,
              y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=1,
              shuffle=False)
    model.reset_states()

print('Predicting')
predicted_output = model.predict(x_train_rnn, batch_size=batch_size)
err = np.mean((y_train-predicted_output)**2)
x_test_rnn = np.reshape(x_test, newshape=(int(nb_samples/5), tsteps, input_dim))
predicted_output_test = model.predict(x_test_rnn, batch_size=batch_size)
err_test = np.mean((y_test-predicted_output_test)**2)
print("Error in reconstruction is %0.2f" % err)
print("Error in test is %0.2f" % err_test)
print('Ploting Results')
plt.figure(figsize=(10, 6))
plt.plot(x_train, predicted_output, 'b', x_train, y_train, '--b')
plt.plot(x_test, predicted_output_test, 'r', x_test, y_test, '--r')
plt.show()
# Out:
# Creating Model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (25, 1, 50)               10400
# _________________________________________________________________
# lstm_1 (LSTM)                (25, 50)                  20200
# _________________________________________________________________
# dense (Dense)                (25, 1)                   51
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________
# Training
# Epoch 0 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 4s 819us/sample - loss: 0.0168
# Epoch 1 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 261us/sample - loss: 0.0284
# Epoch 2 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 268us/sample - loss: 0.0163
# Epoch 3 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 255us/sample - loss: 0.0081
# Epoch 4 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 240us/sample - loss: 0.0061
# Epoch 5 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 272us/sample - loss: 0.0053
# Epoch 6 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 266us/sample - loss: 0.0049
# Epoch 7 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 253us/sample - loss: 0.0049
# Epoch 8 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 257us/sample - loss: 0.0064
# Epoch 9 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 264us/sample - loss: 0.0048
# Epoch 10 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 266us/sample - loss: 0.0043
# Epoch 11 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 259us/sample - loss: 0.0039
# Epoch 12 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 254us/sample - loss: 0.0039
# Epoch 13 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 241us/sample - loss: 0.0040
# Epoch 14 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 254us/sample - loss: 0.0039
# Epoch 15 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 263us/sample - loss: 0.0036
# Epoch 16 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 239us/sample - loss: 0.0039
# Epoch 17 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 272us/sample - loss: 0.0038
# Epoch 18 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 244us/sample - loss: 0.0031
# Epoch 19 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 261us/sample - loss: 0.0033
# Epoch 20 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 248us/sample - loss: 0.0030
# Epoch 21 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 245us/sample - loss: 0.0033
# Epoch 22 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 250us/sample - loss: 0.0035
# Epoch 23 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 248us/sample - loss: 0.0033
# Epoch 24 / 25
# Train on 5000 samples
# 5000/5000 [==============================] - 1s 261us/sample - loss: 0.0033
# Predicting
# Error in reconstruction is 0.85
# Error in test is 1.41
# Ploting Results
